# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
Train = pd.read_csv("DataSets/Train.csv")

# %%
Train.head()
# Out:
#              date_time is_holiday  air_pollution_index  humidity  wind_speed  \
# 0  2012-10-02 09:00:00       None                  121        89           2
# 1  2012-10-02 10:00:00       None                  178        67           3
# 2  2012-10-02 11:00:00       None                  113        66           3
# 3  2012-10-02 12:00:00       None                   20        66           3
# 4  2012-10-02 13:00:00       None                  281        65           3
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0             329                    1          1       288.28       0.0
# 1             330                    1          1       289.36       0.0
# 2             329                    2          2       289.58       0.0
# 3             329                    5          5       290.13       0.0
# 4             329                    7          7       291.14       0.0
#
# ...

# %%
Train['is_holiday'] = np.where(Train['is_holiday'] == "None", "Working Day", Train['is_holiday'])

dateTimeSplits = Train["date_time"].str.split(" ")
Train["Year"] = pd.DataFrame([ item[0].split("-")[0] for item in dateTimeSplits ])
Train["Month"] = pd.DataFrame([ item[0].split("-")[1] for item in dateTimeSplits ])
Train["Day"] = pd.DataFrame([ item[0].split("-")[2] for item in dateTimeSplits ])
Train["hour"] = pd.DataFrame([ item[1].split(":")[0] for item in dateTimeSplits ])

# Train = Train.set_index('date_time')

# %%
data = {'traffic_volume':Train['traffic_volume'], 'date_time':Train['date_time']}
target = pd.DataFrame(data).set_index('date_time')

# %%
# target['traffic_volume'] = Train['traffic_volume']
Train.drop(columns =["traffic_volume","date_time"], inplace = True)

# %%
Train.head()
# Out:
#     is_holiday  air_pollution_index  humidity  wind_speed  wind_direction  \
# 0  Working Day                  121        89           2             329
# 1  Working Day                  178        67           3             330
# 2  Working Day                  113        66           3             329
# 3  Working Day                   20        66           3             329
# 4  Working Day                  281        65           3             329
#
#    visibility_in_miles  dew_point  temperature  rain_p_h  snow_p_h  \
# 0                    1          1       288.28       0.0       0.0
# 1                    1          1       289.36       0.0       0.0
# 2                    2          2       289.58       0.0       0.0
# 3                    5          5       290.13       0.0       0.0
# 4                    7          7       291.14       0.0       0.0
#
#    clouds_all weather_type weather_description  Year Month Day hour
# ...

# %%
Train.nunique()
# Out:
# is_holiday               12
# air_pollution_index     290
# humidity                 88
# wind_speed               17
# wind_direction          361
# visibility_in_miles       9
# dew_point                 9
# temperature            5611
# rain_p_h                353
# snow_p_h                 12
# clouds_all               60
# weather_type             11
# weather_description      38
# Year                      6
# Month                    12
# Day                      31
# hour                     24
# dtype: int64

# %%
from sklearn_pandas import DataFrameMapper
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
column_tuples = [
    ('is_holiday', LabelEncoder()),
    (['air_pollution_index'], StandardScaler()),
    (['humidity'], StandardScaler()),
    (['wind_speed'], StandardScaler()),
    (['wind_direction'], StandardScaler()),
    (['visibility_in_miles'], StandardScaler()),
    (['dew_point'], StandardScaler()),
    (['temperature'], StandardScaler()),
    (['rain_p_h'], StandardScaler()), 
    (['snow_p_h'], StandardScaler()),
    (['clouds_all'], StandardScaler()),
    ('weather_type', LabelEncoder()),
    ('weather_description', LabelEncoder()),
    (['Year'], StandardScaler()),
    (['Month'], MinMaxScaler()),
    (['Day'], MinMaxScaler()),
    (['hour'], MinMaxScaler())
]
mapper = DataFrameMapper(column_tuples,df_out=True)

# %%
mapper_fit = mapper.fit(Train)
Train = mapper_fit.transform(Train)

# %%
Train.head()
# Out:
#    is_holiday  air_pollution_index  humidity  wind_speed  wind_direction  \
# 0          11            -0.404153  1.055720   -0.670405        1.297362
# 1          11             0.276572 -0.249763   -0.183967        1.307378
# 2          11            -0.499693 -0.309103   -0.183967        1.297362
# 3          11            -1.610349 -0.309103   -0.183967        1.297362
# 4          11             1.506654 -0.368443   -0.183967        1.297362
#
#    visibility_in_miles  dew_point  temperature  rain_p_h  snow_p_h  \
# 0            -1.552441  -1.552441     0.612030 -0.008384 -0.032546
# 1            -1.552441  -1.552441     0.692536 -0.008384 -0.032546
# 2            -1.163334  -1.163334     0.708936 -0.008384 -0.032546
# 3             0.003989   0.003989     0.749934 -0.008384 -0.032546
# 4             0.782204   0.782204     0.825223 -0.008384 -0.032546
#
#    clouds_all  weather_type  weather_description      Year     Month  \
# ...

# %%
type(Train)
# Out:
# pandas.core.frame.DataFrame

# %%
import matplotlib.pyplot as plt
# fig_size = plt.rcParams["figure.figsize"]
# fig_size[0] = 20
# fig_size[1] = 5
# plt.rcParams["figure.figsize"] = fig_size

# %%
plt.figure(figsize=(15,5))
plt.plot(target[:200])

# %%
Train[:200].head()
# Out:
#    is_holiday  air_pollution_index  humidity  wind_speed  wind_direction  \
# 0          11            -0.404153  1.055720   -0.670405        1.297362
# 1          11             0.276572 -0.249763   -0.183967        1.307378
# 2          11            -0.499693 -0.309103   -0.183967        1.297362
# 3          11            -1.610349 -0.309103   -0.183967        1.297362
# 4          11             1.506654 -0.368443   -0.183967        1.297362
#
#    visibility_in_miles  dew_point  temperature  rain_p_h  snow_p_h  \
# 0            -1.552441  -1.552441     0.612030 -0.008384 -0.032546
# 1            -1.552441  -1.552441     0.692536 -0.008384 -0.032546
# 2            -1.163334  -1.163334     0.708936 -0.008384 -0.032546
# 3             0.003989   0.003989     0.749934 -0.008384 -0.032546
# 4             0.782204   0.782204     0.825223 -0.008384 -0.032546
#
#    clouds_all  weather_type  weather_description      Year     Month  \
# ...

# %%
import pickle

# %%
pickle.dump(mapper_fit, open('fitted_mapper.pkl', 'wb'))

# %%
def preProcessingScript(dataFrame):
    dataFrame['is_holiday'] = np.where(dataFrame['is_holiday'] == "None", "Working Day", dataFrame['is_holiday'])
    dateTimeSplits = dataFrame["date_time"].str.split(" ")
    dataFrame["Year"] = pd.DataFrame([ item[0].split("-")[0] for item in dateTimeSplits ])
    dataFrame["Month"] = pd.DataFrame([ item[0].split("-")[1] for item in dateTimeSplits ])
    dataFrame["Day"] = pd.DataFrame([ item[0].split("-")[2] for item in dateTimeSplits ])
    dataFrame["hour"] = pd.DataFrame([ item[1].split(":")[0] for item in dateTimeSplits ])
    dataFrame.drop(columns =["date_time"], inplace = True)
    mapper_fit = pickle.load(open('fitted_mapper.pkl', 'rb'))
    return mapper_fit.transform(dataFrame)

# %%
Train.shape
# Out:
# (33750, 17)

# %% [markdown]
# # Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, Activation, Flatten, TimeDistributed, AveragePooling1D
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import KFold, cross_val_score
from tensorflow.keras.callbacks import TensorBoard
import time


def baseline_model():
    model = Sequential()
    model.add(Dense(130, input_dim=17, kernel_initializer='normal', activation='relu'))
    model.add(Dense(116, kernel_initializer='normal', activation='relu'))
    model.add(Dense(100, kernel_initializer='normal', activation='relu'))
    model.add(Dense(66, kernel_initializer='normal', activation='relu'))
    model.add(Flatten())
    model.add(Dropout(0.2))
    model.add(Dense(60, kernel_initializer='normal', activation='relu'))
    model.add(Dense(54, kernel_initializer='normal', activation='relu'))
    model.add(Dense(45, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, kernel_initializer='normal'))
    model.compile(loss='mean_squared_error', optimizer='rmsprop')
    return model

# %%
def build_LSTM_model():
    sequence_length = 100
    model = Sequential()
    layers = {'input': 17, 'hidden1': 64, 'hidden2': 256, 'hidden3': 100, 'output': 1}
    
    model.add(Dense(100, input_dim=17, kernel_initializer='normal', activation='relu'))

#     model.add(LSTM(
# #                     input_length=sequence_length - 1,
#                     input_shape = (100,17),
# #                     input_dim=layers['input'],
#                     units=100,
#                     return_sequences=True))
#     model.add(TimeDistributed(Dense(1)))
#     model.add(AveragePooling1D())
    model.add(Flatten())
    model.add(Dropout(0.2))

    model.add(LSTM(
            layers['hidden2'],
            return_sequences=True))
    model.add(Dropout(0.2))

    model.add(LSTM(
            layers['hidden3'],
            return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Flatten())

    model.add(Dense(layers['output']))
    model.add(Activation("linear"))

    start = time.time()
    model.compile(loss="mse", optimizer="rmsprop")
    print ("Compilation Time : "+ str(time.time() - start))
    return model

# %%
# model = baseline_model()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 130)               2340
# _________________________________________________________________
# dense_1 (Dense)              (None, 116)               15196
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               11700
# _________________________________________________________________
# dense_3 (Dense)              (None, 66)                6666
# _________________________________________________________________
# flatten (Flatten)            (None, 66)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 66)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 60)                4020
# ...

# %%
dataForT = Train
targetForT = target

# %%
NAME = "Traffic-{}".format(int(time.time()))
tensorboard = TensorBoard(log_dir="logs\{}".format(NAME))
fM= model.fit(dataForT, targetForT, epochs=500, batch_size=1100, validation_split=0.01, verbose=2,callbacks=[tensorboard] )
# Out:
# Train on 33412 samples, validate on 338 samples
# Epoch 1/500
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-27-abde2faaa23b> in <module>()
#       1 NAME = "Traffic-{}".format(int(time.time()))
#       2 tensorboard = TensorBoard(log_dir="logs\{}".format(NAME))
# ----> 3 fM= model.fit(dataForT, targetForT, epochs=500, batch_size=1100, validation_split=0.01, verbose=2,callbacks=[tensorboard] )
#
# c:\users\chira\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     778           validation_steps=validation_steps,
# ...

# %%
filename = "Train1\DLModel-{}.h5".format(int(time.time()))

# %%
model.save(filename)

# %%
# from tensorflow import keras

# %%
model = keras.models.load_model("Train1\DLModel-1564821463.h5")
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# c:\users\chira\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#
# c:\users\chira\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#
# c:\users\chira\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# ...

# %%
rcmodel = keras.models.load_model(filename)

# %%
orig = pd.Series(list(target["traffic_volume"]))

# %%
pred = model.predict(pd.DataFrame(Train))

# %%
ins = dataForT.shape[1:]

# %%
pred_list = [p[0] for p in pred]

# %%
predictions = pd.Series(pred_list)

# %%
rcpred = rcmodel.predict(pd.DataFrame(Train))

# %%
rcpredList = pd.Series([p[0] for p in rcpred])

# %%
np.all(rcpredList)==np.all(predictions)
# Out:
# True

# %%
for i, j in zip(predictions,rcpredList):
    if i!=j:
        print("Fail")

# %%
plt.figure(figsize=(15,5))
plt.plot(orig[:300],label="Original Data")
plt.plot(predictions[:300],label="Predictions")
# plt.plot(rcpredList,label="RC Predictions")
plt.legend(loc='upper left')
plt.title("Comaprison of flow Between Original and predictions")
# Out:
# Text(0.5,1,'Comaprison of flow Between Original and predictions')

# %%
plt.figure(figsize=(15,5))
plt.plot(orig,label="Original Data")
plt.plot(predictions,label="Predictions")
# plt.plot(rcpredList,label="RC Predictions")
plt.legend(loc='upper left')
plt.title("Comaprison of flow Between Original and predictions")
# Out:
# Text(0.5,1,'Comaprison of flow Between Original and predictions')

# %%
rcmodel

# %%
from sklearn.linear_model import LinearRegression

# %%
LRmodel = LinearRegression()

# %%
LRmodel.fit(np.array(predictions.tolist()).reshape(-1, 1),np.array(orig.tolist()).reshape(-1, 1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d4b5fe75f95a> in <module>()
# ----> 1 LRmodel.fit(np.array(predictions.tolist()).reshape(-1, 1),np.array(orig.tolist()).reshape(-1, 1))
#
# NameError: name 'np' is not defined

# %%
filename = "Train1\LRModel{}.pkl".format(int(time.time()))
pickle.dump(LRmodel, open(filename, 'wb'))

# %%
RCLRModel = pickle.load(open('Train1\LRModel1564824033.pkl', 'rb'))

# %%
continuedPred = LRmodel.predict(pred)

# %%
continuedPredSeries = pd.Series([p[0] for p in continuedPred])

# %%
plt.figure(figsize=(15,6))
plt.scatter(orig[:300], pred[:300],color='r')
plt.scatter(orig[:300],continuedPred[:300],color='g')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c20961a57070> in <module>()
# ----> 1 plt.figure(figsize=(15,6))
#       2 plt.scatter(orig[:300], pred[:300],color='r')
#       3 plt.scatter(orig[:300],continuedPred[:300],color='g')
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize=(15,5))
plt.scatter(predictions.tolist()[:300], orig[:300],color='g')
plt.plot(np.array(predictions.tolist())[:200], continuedPred[:200],color='k')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.scatter(predictions.tolist(), orig,color='g')
plt.plot(predictions.tolist(), continuedPred,color='k')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(orig[-500:],label="Original Data")
# plt.plot(predictions,label="Predictions")
plt.plot(continuedPredSeries[-500:],label="Continued Predictions")
plt.legend(loc='upper left')
plt.title("Comaprison of flow Between Original and predictions")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-522c1f9466ee> in <module>()
#       1 plt.figure(figsize=(15,5))
# ----> 2 plt.plot(orig[-500:],label="Original Data")
#       3 # plt.plot(predictions,label="Predictions")
#       4 plt.plot(continuedPredSeries[-500:],label="Continued Predictions")
#       5 plt.legend(loc='upper left')
#
# NameError: name 'orig' is not defined

# %%
plt.figure(figsize=(15,5))
plt.plot(orig,label="Original Data")
# plt.plot(predictions,label="Predictions")
plt.plot(continuedPredSeries,label="Continued Predictions")
plt.legend(loc='upper left')
plt.title("Comaprison of flow Between Original and predictions")
# Out:
# Text(0.5,1,'Comaprison of flow Between Original and predictions')

# %%
Test_data = pd.read_csv("DataSets/Test.csv")

# %%
Test_data.head()
# Out:
#              date_time is_holiday  air_pollution_index  humidity  wind_speed  \
# 0  2017-05-18 00:00:00       None                   73        63           1
# 1  2017-05-18 00:00:00       None                  251        63           1
# 2  2017-05-18 00:00:00       None                   75        56           1
# 3  2017-05-18 01:00:00       None                   98        56           1
# 4  2017-05-18 01:00:00       None                  283        56           1
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0              27                    4          4       285.15       0.0
# 1              27                    4          4       285.15       0.0
# 2               0                    1          1       285.15       0.0
# 3             351                    2          2       284.79       0.0
# 4             351                    1          1       284.79       0.0
#
#    snow_p_h  clouds_all weather_type      weather_description
# ...

# %%
outputDate = Test_data["date_time"]

# %%
preProcessedtestData = preProcessingScript(Test_data)

# %%
firstPrediction = model.predict(pd.DataFrame(preProcessedtestData))

# %%
testDataPredictions = LRmodel.predict(firstPrediction)

# %%
plt.figure(figsize=(15,5))
plt.plot(testDataPredictions[:300],label="Predictions")
plt.legend(loc='upper left')
plt.title("Test Data predictions")
# Out:
# Text(0.5,1,'Test Data predictions')

# %%
plt.figure(figsize=(15,5))
plt.plot(testDataPredictions[:300],label="Predictions")
plt.plot(firstPrediction[:300],label="First Predictions")
# plt.plot(continuedPredSeries,label="Continued Predictions")
plt.legend(loc='upper left')
plt.title("Test Data predictions")
# Out:
# Text(0.5,1,'Test Data predictions')

# %%
testDataPredictionsIntList = [int(round(item[0])) for item in testDataPredictions]

# %%
data = {'date_time': outputDate,'traffic_volume':testDataPredictionsIntList}
filename = "Train1\Prediction{}.csv".format(int(time.time()))
output = pd.DataFrame(data)
output.to_csv(filename, index=False)

# %%
output.head()
# Out:
#              date_time  traffic_volume
# 0  2017-05-18 00:00:00             498
# 1  2017-05-18 00:00:00             448
# 2  2017-05-18 00:00:00             788
# 3  2017-05-18 01:00:00             718
# 4  2017-05-18 01:00:00             337

# %%
def predict(model,data):
    outputDate = data["date_time"]
    return postProcessingScript(model.predict(pd.DataFrame(preProcessingScript(data))),outputDate)

# %%
def postProcessingScript(predictions,index):
    import pandas as pd
    import numpy as np
    RCLRModel = pickle.load(open('Train1\LRModel1564824033.pkl', 'rb'))
    filteredPredictionsIntList = [int(round(item[0])) for item in RCLRModel.predict(predictions)]
    data = {'date_time': index,'traffic_volume':filteredPredictionsIntList}
    output = pd.DataFrame(data)
    np.where(output['traffic_volume']  <= 0 , output['traffic_volume'].rolling(2).median(), output['traffic_volume'])
    return output

# %%
break
# Out:
#   File "<ipython-input-248-6aaf1f276005>", line 1
#     break
#          ^
# SyntaxError: 'break' outside loop

# %%
dataForT = Train[:10000]
targetForT = target[:10000]

# %%
seed = 7
np.random.seed(seed)
# evaluate model with standardized dataset
estimator = KerasRegressor(build_fn=baseline_model, epochs=100, batch_size=25, verbose=0)

# %%
kfold = KFold(n_splits=10, random_state=seed)
results = cross_val_score(estimator, dataForT, targetForT, cv=kfold)
print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))

# %%
predict(processedTestData[:10])

# %%
Test = pd.read_csv("DataSets/Test.csv")

# %%
processedTestData = preProcessingScript(Test)

# %%
processedTestData.head()

# %% [markdown]
# # LSTM

# %%
def build_LSTM_model():
    sequence_length = 100
    model = Sequential()
    layers = {'input': 17, 'hidden1': 64, 'hidden2': 256, 'hidden3': 100, 'output': 1}

    model.add(LSTM(
#                     input_length=sequence_length - 1,
                    input_shape = (100,17),
#                     input_dim=layers['input'],
                    units=100,
                    return_sequences=True))
#     model.add(TimeDistributed(Dense(1)))
#     model.add(AveragePooling1D())
    
#     model.add(Dropout(0.2))

#     model.add(LSTM(
#             layers['hidden2'],
#             return_sequences=True))
#     model.add(Dropout(0.2))

#     model.add(LSTM(
#             layers['hidden3'],
#             return_sequences=False))
#     model.add(Dropout(0.2))
    model.add(Flatten())

    model.add(Dense(layers['output']))
    model.add(Activation("linear"))

    start = time.time()
    model.compile(loss="mse", optimizer="rmsprop")
    print ("Compilation Time : "+ str(time.time() - start))
    return model

# %%
def run_network(model=None, data=None):
    global_start_time = time.time()

    if data is None:
        print('Loading data... ')
        # train on first 700 samples and test on next 300 samples (has anomaly)
        X_train, y_train, X_test, y_test = get_split_prep_data(0, 700, 500, 1000)
    else:
        X_train, y_train, X_test, y_test = data

    print('\nData Loaded. Compiling...\n')

    if model is None:
        model = build_model()

    try:
        print("Training...")
        model.fit(
                X_train, y_train,
                batch_size=batch_size, nb_epoch=epochs, validation_split=0.05)
        print("Predicting...")
        predicted = model.predict(X_test)
        print("Reshaping predicted")
        predicted = np.reshape(predicted, (predicted.size,))
    except KeyboardInterrupt:
        print("prediction exception")
        print ('Training duration (s) : '+ str(time.time() - global_start_time))
        return model, y_test, 0

    try:
        plt.figure(1)
        plt.subplot(311)
        plt.title("Actual Test Signal w/Anomalies")
        plt.plot(y_test[:len(y_test)], 'b')
        plt.subplot(312)
        plt.title("Predicted Signal")
        plt.plot(predicted[:len(y_test)], 'g')
        plt.subplot(313)
        plt.title("Squared Error")
        mse = ((y_test - predicted) ** 2)
        plt.plot(mse, 'r')
        plt.show()
    except Exception as e:
        print("plotting exception")
        print(str(e))
    print ('Training duration (s) : '+ str(time.time() - global_start_time))

    return model, y_test, predicted
